# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('data/COVID19MEXICO2021.csv')
# Out:
# C:\Users\daniel\AppData\Local\Temp\ipykernel_4260\3610430925.py:1: DtypeWarning: Columns (38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/COVID19MEXICO2021.csv')

# %%
df["ID_REGISTRO"].duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2022-08-09      z53cb3       2      12           9     2
# 1          2022-08-09      zze974       1       6          24     1
# 2          2022-08-09      zz7202       1      12          16     2
# 3          2022-08-09      z405fd       1      12           9     2
# 4          2022-08-09      z26b82       2      12           9     1
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 0            9            9              2              1    2021-01-16
# 1           24           24             35              1    2021-02-28
# 2           16           16            112              1    2021-01-13
# 3            9            9             11              1    2021-01-25
# 4            9            9              7              1    2021-01-14
#
#   FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 0     2021-01-13  9999-99-99        97         2    26             1
# 1     2021-02-20  9999-99-99        97        99    34             1
# 2     2021-01-13  9999-99-99        97         2    41             1
# 3     2021-01-17  9999-99-99        97         2    25             1
# 4     2021-01-10  9999-99-99        97         2    20             1
#
#    EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  INMUSUPR  \
# 0        97                   2         2         2     2     2         2
# 1         2                   2         2         2     2     2         2
# 2        97                   2         2         2     2     2         2
# 3        97                   2         2         2     2     2         2
# 4         2                   2         2         2     2     2         2
#
#    HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  \
# 0             2         2               2         2              2
# 1             2         2               2         2              2
# 2             2         2               2         2              2
# 3             2         2               2         2              2
# 4             2         2               2         2              2
#
#    TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# 0           2          1                 2             97
# 1           2          1                 1              2
# 2           1          1                 1              2
# 3           2          1                 2             97
# 4           2          2                 2             97
#
#    TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  \
# 0                      1                   2                    7        99
# 1                      2                  97                    7        99
# 2                      2                  97                    7        99
# 3                      1                   2                    7        99
# 4                      1                   2                    7        99
#
#   PAIS_NACIONALIDAD PAIS_ORIGEN  UCI
# 0            México          97   97
# 1            México          97   97
# 2            México          97   97
# 3            México          97   97
# 4            México          97   97

# %% [markdown]
# Se seleccionan unicamente los registros que sean confirmados y que sean casos positivos de COVID-19

# %% [markdown]
# Según el catalogo de datos, los valores 1,2,3 son casos confirmados

# %%
df.columns = ['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
       'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
       'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
       'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'INDIGENA',
       'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
       'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
       'OTRO_CASO', 'TOMA_MUESTRA_LAB', 'RESULTADO_LAB',
       'TOMA_MUESTRA_ANTIGENO', 'RESULTADO_ANTIGENO', 'CLASIFICACION_FINAL_COVID',
       'MIGRANTE', 'PAIS_NACIONALIDAD', 'PAIS_ORIGEN', 'UCI']

# %%
df["CLASIFICACION_FINAL_COVID"].value_counts()
# Out:
# CLASIFICACION_FINAL_COVID
# 7    6054994
# 3    2302159
# 6     226709
# 1     220248
# 5      20335
# 2       4242
# 4       1658
# Name: count, dtype: int64

# %%
df[(df["CLASIFICACION_FINAL_COVID"] == 1) | (df["CLASIFICACION_FINAL_COVID"] == 2) | (df["CLASIFICACION_FINAL_COVID"] == 3)]
# Out:
#         FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 6                2022-08-09      1009d6       1      12          30     1
# 10               2022-08-09      0f6295       1       6          24     1
# 16               2022-08-09     gzza9a9       1      12           9     1
# 31               2022-08-09     gz2a60a       2       4          15     1
# 57               2022-08-09     gz2fa87       2       4          26     1
# ...                     ...         ...     ...     ...         ...   ...
# 8830180          2022-08-09     m02e1f4       2      12          15     1
# 8830182          2022-08-09     m0d8232       2      12          15     1
# 8830186          2022-08-09     m1bf9c0       2      12          15     1
# 8830205          2022-08-09     m0dd435       2      12          15     2
# 8830208          2022-08-09     m07ede2       2      12          15     2
#
#          ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  \
# 6                 30           30             85              1    2021-02-17
# 10                24           24             28              1    2021-01-29
# 16                 9            9              4              1    2021-09-01
# 31                 9           15             60              1    2022-01-04
# 57                25           26             55              1    2021-12-24
# ...              ...          ...            ...            ...           ...
# 8830180           15           15             64              1    2021-09-28
# 8830182           15           15             64              1    2021-09-30
# 8830186           15           15             60              1    2021-10-07
# 8830205           15           15             60              1    2021-10-06
# 8830208           15           15             60              1    2021-10-05
#
#         FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  EDAD  NACIONALIDAD  \
# 6           2021-02-14  9999-99-99        97         2    36             1
# 10          2021-01-27  9999-99-99        97         2    63             1
# 16          2021-09-01  9999-99-99        97         2    18             1
# 31          2021-12-31  9999-99-99        97         2    33             1
# 57          2021-12-21  9999-99-99        97         2    44             1
# ...                ...         ...       ...       ...   ...           ...
# 8830180     2021-09-25  9999-99-99        97        99    22             1
# 8830182     2021-09-27  9999-99-99        97        99    21             1
# 8830186     2021-10-01  9999-99-99        97        99    18             1
# 8830205     2021-10-03  9999-99-99        97        99    31             1
# 8830208     2021-10-03  9999-99-99        97        99    67             1
#
#          EMBARAZO  HABLA_LENGUA_INDIG  INDIGENA  DIABETES  EPOC  ASMA  \
# 6               2                   2         2         1     2     2
# 10              2                   2         2         2     2     1
# 16              1                   2         2         2     2     2
# 31              2                   2         2         2     2     2
# 57              2                   2         2         2     2     2
# ...           ...                 ...       ...       ...   ...   ...
# 8830180         2                  99        99         2     2     2
# 8830182         2                  99        99         2     2     2
# 8830186         2                  99        99         2     2     2
# 8830205        97                  99        99         2     2     2
# 8830208        97                  99        99         2     2     2
#
#          INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 6               2             2         2               2         2
# 10              2             2         1               1         2
# 16              2             2         2               2         2
# 31              2             2         2               2         2
# 57              2             1         2               2         1
# ...           ...           ...       ...             ...       ...
# 8830180         2             2        98               2         2
# 8830182         2             2        98               2         2
# 8830186         2             2        98               2         2
# 8830205         2             2        98               2         2
# 8830208         2             2        98               2         2
#
#          RENAL_CRONICA  TABAQUISMO  OTRO_CASO  TOMA_MUESTRA_LAB  \
# 6                    2           2          2                 1
# 10                   2           2         99                 1
# 16                   2           2          2                 2
# 31                   2           2          1                 2
# 57                   2           2          2                 2
# ...                ...         ...        ...               ...
# 8830180              2           2         99                 2
# 8830182              2           2         99                 2
# 8830186              2           2         99                 2
# 8830205              2           2         99                 2
# 8830208              2           2         99                 2
#
#          RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# 6                    1                      2                  97
# 10                   1                      2                  97
# 16                  97                      1                   2
# 31                  97                      1                   1
# 57                  97                      1                   1
# ...                ...                    ...                 ...
# 8830180             97                      1                   1
# 8830182             97                      1                   1
# 8830186             97                      1                   1
# 8830205             97                      1                   1
# 8830208             97                      1                   1
#
#          CLASIFICACION_FINAL_COVID  MIGRANTE PAIS_NACIONALIDAD PAIS_ORIGEN  \
# 6                                3        99            México          97
# 10                               3        99            México          97
# 16                               1        99            México          97
# 31                               3        99            México          97
# 57                               3        99            México          97
# ...                            ...       ...               ...         ...
# 8830180                          3        99            México          97
# 8830182                          3        99            México          97
# 8830186                          3        99            México          97
# 8830205                          3        99            México          97
# 8830208                          3        99            México          97
#
#          UCI
# 6         97
# 10        97
# 16        97
# 31        97
# 57        97
# ...      ...
# 8830180   97
# 8830182   97
# 8830186   97
# 8830205   97
# 8830208   97
#
# [2526649 rows x 40 columns]

# %%
df = df[(df["CLASIFICACION_FINAL_COVID"] == 1) | (df["CLASIFICACION_FINAL_COVID"] == 2) | (df["CLASIFICACION_FINAL_COVID"] == 3)]

# %% [markdown]
# ### Se crea una nueva variable que es saber si la persona falleció o no

# %%
df["DEFUNCION"] = np.where(df['FECHA_DEF'] == '9999-99-99', 2, 1)

# %% [markdown]
# ### Se pasa a formato fecha

# %% [markdown]
# #### Primero se pasa a nulos los valores de 9999-99-99, que representan lo que no han fallecido

# %%
df['FECHA_DEF'] = df['FECHA_DEF'].replace('9999-99-99', np.nan)

# %%
df['FECHA_DEF'] = pd.to_datetime(df['FECHA_DEF'])

# %%
df['FECHA_SINTOMAS'] = pd.to_datetime(df['FECHA_SINTOMAS'])
df['FECHA_ACTUALIZACION'] = pd.to_datetime(df['FECHA_ACTUALIZACION'])

# %%
df.FECHA_DEF.describe()
# Out:
# count                           141499
# mean     2021-05-29 18:33:23.853030400
# min                2021-01-01 00:00:00
# 25%                2021-02-11 00:00:00
# 50%                2021-05-15 00:00:00
# 75%                2021-08-30 00:00:00
# max                2022-07-29 00:00:00
# Name: FECHA_DEF, dtype: object

# %%
df.FECHA_SINTOMAS.describe()
# Out:
# count                          2526649
# mean     2021-06-21 09:45:30.052492800
# min                2021-01-01 00:00:00
# 25%                2021-03-06 00:00:00
# 50%                2021-07-22 00:00:00
# 75%                2021-08-28 00:00:00
# max                2021-12-31 00:00:00
# Name: FECHA_SINTOMAS, dtype: object

# %%
df.FECHA_ACTUALIZACION.describe()
# Out:
# count                2526649
# mean     2022-08-09 00:00:00
# min      2022-08-09 00:00:00
# 25%      2022-08-09 00:00:00
# 50%      2022-08-09 00:00:00
# 75%      2022-08-09 00:00:00
# max      2022-08-09 00:00:00
# Name: FECHA_ACTUALIZACION, dtype: object

# %% [markdown]
# Vamos a calcular el numero de dias que han pasado desde la fecha de ingreso/sintomas hasta la fecha de defuncion

# %%
df['DIAS_SINTOMAS_DEF'] = (df['FECHA_DEF'] - df['FECHA_SINTOMAS']).dt.days
df['DIAS_SINTOMAS_ACT'] = (df['FECHA_ACTUALIZACION'] - df['FECHA_SINTOMAS']).dt.days

# %%
df[df['DEFUNCION']== 1][['DIAS_SINTOMAS_DEF','DIAS_SINTOMAS_ACT']]
# Out:
#          DIAS_SINTOMAS_DEF  DIAS_SINTOMAS_ACT
# 124                    9.0                536
# 136                   12.0                473
# 420                   11.0                561
# 462                   11.0                561
# 482                   17.0                560
# ...                    ...                ...
# 8780459                7.0                286
# 8781718               23.0                285
# 8784505               13.0                279
# 8790898                3.0                267
# 8801216                4.0                239
#
# [141499 rows x 2 columns]

# %%
df.shape
# Out:
# (2526649, 43)

# %%
df.DEFUNCION.value_counts()
# Out:
# DEFUNCION
# 2    2385150
# 1     141499
# Name: count, dtype: int64

# %% [markdown]
# Seleccionamos las columnas que nos interesan para el análisis

# %%
df_cox = df[["DEFUNCION","DIAS_SINTOMAS_ACT","DIAS_SINTOMAS_DEF", "NEUMONIA", "DIABETES", "EPOC", "ASMA", "INMUSUPR", "HIPERTENSION", "OTRA_COM", "CARDIOVASCULAR", "OBESIDAD", "RENAL_CRONICA", "TABAQUISMO"]]

# %%
df_cox.head()
# Out:
#     DEFUNCION  DIAS_SINTOMAS_ACT  DIAS_SINTOMAS_DEF  NEUMONIA  DIABETES  EPOC  \
# 6           2                541                NaN         2         1     2
# 10          2                559                NaN         2         2     2
# 16          2                342                NaN         2         2     2
# 31          2                221                NaN         2         2     2
# 57          2                231                NaN         2         2     2
#
#     ASMA  INMUSUPR  HIPERTENSION  OTRA_COM  CARDIOVASCULAR  OBESIDAD  \
# 6      2         2             2         2               2         2
# 10     1         2             2         1               1         2
# 16     2         2             2         2               2         2
# 31     2         2             2         2               2         2
# 57     2         2             1         2               2         1
#
#     RENAL_CRONICA  TABAQUISMO
# 6               2           2
# 10              2           2
# 16              2           2
# 31              2           2
# 57              2           2

# %%
df_cox["DEFUNCION"].value_counts()
# Out:
# DEFUNCION
# 2    2385150
# 1     141499
# Name: count, dtype: int64

# %% [markdown]
# Camabiar valores para que 1 sea si (prensenta condicion o afirmacion de nombre de columna) y 0 sea no (no presenta condicion o negación de nombre de columna)

# %%
df_cox.replace([1,2], [1,0], inplace=True)
# Out:
# C:\Users\daniel\AppData\Local\Temp\ipykernel_4260\3344868473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cox.replace([1,2], [1,0], inplace=True)

# %% [markdown]
# Vamos a eliminar los registros con valores nulos

# %%
day_variables = df_cox[["DIAS_SINTOMAS_ACT","DIAS_SINTOMAS_DEF"]]

# %%
df_cox = df_cox.drop(day_variables, axis=1)

# %%
df_cox.replace([97,98,99], np.nan, inplace=True)

# %%
df_cox = df_cox.dropna()

# %%
df_cox["DEFUNCION"].value_counts()
# Out:
# DEFUNCION
# 0    2361578
# 1     139904
# Name: count, dtype: int64

# %%
df_cox = df_cox.astype(int)

# %%
df_cox = df_cox.join(day_variables, how='left')

# %%
df_cox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2501482 entries, 6 to 8708284
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   DEFUNCION          int32
#  1   NEUMONIA           int32
#  2   DIABETES           int32
#  3   EPOC               int32
#  4   ASMA               int32
#  5   INMUSUPR           int32
#  6   HIPERTENSION       int32
#  7   OTRA_COM           int32
#  8   CARDIOVASCULAR     int32
#  9   OBESIDAD           int32
#  10  RENAL_CRONICA      int32
#  11  TABAQUISMO         int32
#  12  DIAS_SINTOMAS_ACT  int64
#  13  DIAS_SINTOMAS_DEF  float64
# dtypes: float64(1), int32(12), int64(1)
# memory usage: 236.3 MB

# %%
df_cox.columns
# Out:
# Index(['DEFUNCION', 'NEUMONIA', 'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR',
#        'HIPERTENSION', 'OTRA_COM', 'CARDIOVASCULAR', 'OBESIDAD',
#        'RENAL_CRONICA', 'TABAQUISMO', 'DIAS_SINTOMAS_ACT',
#        'DIAS_SINTOMAS_DEF'],
#       dtype='object')

# %% [markdown]
# En los dias transcurridos hasta el evento, para los pacientes que fallecieron, los valores se reemplazan por los días desde la fecha del inicio de los sintomas, hasta la fecha de defuncion. Para los pacientes que no fallecieron, el valor de dias transcurridos se reemplazan por los dias desde el inicio de los sintomas hasta la ultima fecha de actualización del conjunto de datos(representa el ultimo dia de estudio)

# %%
df_cox["DIAS_TRANSCURRIDOS"] = np.where(df_cox['DEFUNCION'] == 0, df_cox["DIAS_SINTOMAS_ACT"], df_cox["DIAS_SINTOMAS_DEF"])

# %%
df_cox.drop(["DIAS_SINTOMAS_ACT", "DIAS_SINTOMAS_DEF"], axis=1, inplace=True)

# %%
df_cox.columns = ['DEFUNCION', 'NEUMONIA', 'DIABETES', 'EPOC', 'ASMA', 'INMUSUPR',
       'HIPERTENSION', 'OTRA_COM', 'CARDIOVASCULAR', 'OBESIDAD',
       'RENAL_CRONICA', 'TABAQUISMO', 'DIAS_SINTOMAS_DEF']

# %%
df_cox = df_cox.astype(int)

# %%
df_cox.head()
# Out:
#     DEFUNCION  NEUMONIA  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  \
# 6           0         0         1     0     0         0             0
# 10          0         0         0     0     1         0             0
# 16          0         0         0     0     0         0             0
# 31          0         0         0     0     0         0             0
# 57          0         0         0     0     0         0             1
#
#     OTRA_COM  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  \
# 6          0               0         0              0           0
# 10         1               1         0              0           0
# 16         0               0         0              0           0
# 31         0               0         0              0           0
# 57         0               0         1              0           0
#
#     DIAS_SINTOMAS_DEF
# 6                 541
# 10                559
# 16                342
# 31                221
# 57                231

# %%
df_cox.to_csv('data/df_cox2021.csv', index=False)
